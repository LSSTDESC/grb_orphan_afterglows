# %% [markdown]
# # Gaussian

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import math

# %% [markdown]
# ### Open data

# %%
file_open = open('../data/simulations/lc_configs_G_100000.pkl', 'rb')
lc_open = pickle.load(file_open)
file_open.close()

# %%
file_open2 = open('../data/simulations/all_dico_results_G_015_100000.pkl', 'rb')
lc_config = pickle.load(file_open2)
file_open2.close()

# %% [markdown]
# ### Parameter distributions
# #### Energy

# %%
E_th = []
E_obs = []
E = []

for i in range(len(lc_open)):
    if lc_open[i] == 0:
        continue
    else:
        E_obs.append((lc_open[i]['config']['E0']))
        
for i in range(len(lc_config)):
    if lc_config[i] == 0:
        continue
    else:
        E.append((lc_config[i]['config']['E0']))
        if lc_config[i]['t_obs'] > 7. and lc_config[i]['axis'] == 'off':
            E_th.append((lc_config[i]['config']['E0']))

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(np.log10(E), bins=100, alpha=0.5, color='skyblue', edgecolor='dodgerblue', label='all configurations')
plt.hist(np.log10(E_th), bins=60, alpha=0.5, color='orange', edgecolor='orangered', label='theoritical observable configurations')
plt.hist(np.log10(E_obs), bins=60, alpha=0.5, color='yellowgreen', edgecolor='darkolivegreen', label='observable configurations by Rubin LSST')

plt.xlabel(r'$log_{10}(E_0)$ ($E_0$ in ergs)')
plt.ylabel('number of GRBs')
plt.legend()

# %% [markdown]
# #### Circumburst density

# %%
n_th = []
n_obs = []
n = []

for i in range(len(lc_open)):
    if lc_open[i] == 0:
        continue
    else:
        n_obs.append((lc_open[i]['config']['n0']))
        
for i in range(len(lc_config)):
    if lc_config[i] == 0:
        continue
    else:
        n.append((lc_config[i]['config']['n0']))
        if lc_config[i]['t_obs'] > 7. and lc_config[i]['axis'] == 'off':
            n_th.append((lc_config[i]['config']['n0']))

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(np.log10(n), bins=100, alpha=0.5, color='skyblue', edgecolor='dodgerblue', label='all configurations')
plt.hist(np.log10(n_th), bins=100, alpha=0.5, color='orange', edgecolor='orangered', label='theoritical observable configurations')
plt.hist(np.log10(n_obs), bins=100, alpha=0.5, color='yellowgreen', edgecolor='darkolivegreen', label='observable configurations by Rubin LSST')

plt.xlabel(r'$log_{10}(n_0)$ ($n_0$ in cm$^{-3}$)')
plt.ylabel('number of GRBs')
plt.legend()

# %% [markdown]
# #### Redshift

# %%
z_th = []
z_obs = []
z = []

for i in range(len(lc_open)):
    if lc_open[i] == 0:
        continue
    else:
        z_obs.append((lc_open[i]['config']['z']))
        
for i in range(len(lc_config)):
    if lc_config[i] == 0:
        continue
    else:
        z.append((lc_config[i]['config']['z']))
        if lc_config[i]['t_obs'] > 7. and lc_config[i]['axis'] == 'off':
            z_th.append((lc_config[i]['config']['z']))

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(z, bins=100, alpha=0.5, color='skyblue', edgecolor='dodgerblue', label='all configurations')
plt.hist(z_th, bins=100, alpha=0.5, color='orange', edgecolor='orangered', label='theoritical observable configurations')
plt.hist(z_obs, bins=100, alpha=0.5, color='yellowgreen', edgecolor='darkolivegreen', label='observable configurations by Rubin LSST')

plt.xlabel('z')
plt.ylabel('number of GRBs')
plt.legend()

# %% [markdown]
# #### $\theta_{obs}$

# %%
tObs_th = []
tObs_obs = []
tObs = []

for i in range(len(lc_open)):
    if lc_open[i] == 0:
        continue
    else:
        tObs_obs.append((lc_open[i]['config']['thetaObs']))
        
for i in range(len(lc_config)):
    if lc_config[i] == 0:
        continue
    else:
        tObs.append((lc_config[i]['config']['thetaObs']))
        if lc_config[i]['t_obs'] > 7. and lc_config[i]['axis'] == 'off':
            tObs_th.append((lc_config[i]['config']['thetaObs']))

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(np.degrees(tObs), bins=100, alpha=0.5, color='skyblue', edgecolor='dodgerblue', label='all configurations')
plt.hist(np.degrees(tObs_th), bins=100, alpha=0.5, color='orange', edgecolor='orangered', label='theoritical observable configurations')
plt.hist(np.degrees(tObs_obs), bins=100, alpha=0.5, color='yellowgreen', edgecolor='darkolivegreen', label='observable configurations by Rubin LSST')

plt.xlabel(r'$\theta_{obs}$ (in degrees)')
plt.ylabel('number of GRBs')
plt.legend()

# %% [markdown]
# #### $\theta_w$

# %%
tW_th = []
tW_obs = []
tW = []

for i in range(len(lc_open)):
    if lc_open[i] == 0:
        continue
    else:
        tW_obs.append((lc_open[i]['config']['thetaWing']))
        
for i in range(len(lc_config)):
    if lc_config[i] == 0:
        continue
    else:
        tW.append((lc_config[i]['config']['thetaWing']))
        if lc_config[i]['t_obs'] > 7. and lc_config[i]['axis'] == 'off':
            tW_th.append((lc_config[i]['config']['thetaWing']))

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(np.degrees(tW), bins=100, alpha=0.5, color='skyblue', edgecolor='dodgerblue', label='all configurations')
plt.hist(np.degrees(tW_th), bins=80, alpha=0.5, color='orange', edgecolor='orangered', label='theoritical observable configurations')
plt.hist(np.degrees(tW_obs), bins=80, alpha=0.5, color='yellowgreen', edgecolor='darkolivegreen', label='observable configurations by Rubin LSST')

plt.xlabel(r'$\theta_w$ (in degrees)')
plt.ylabel('number of GRBs')
plt.legend()

# %% [markdown]
# ### Result distributions
# #### Mean minimal magnitude

# %%
mag_min = []

for i in range(len(lc_open)):
    
    if lc_open[i]==0:
        mag_min.append(np.nan)
        
    else:
        mag = []
        
        for j in range(len(lc_open[i]['mags'])):
            if lc_open[i]['mags'][j] < lc_open[i]['mags_lim'][j]:
                mag.append(lc_open[i]['mags'][j])
                
        if len(mag)==0:
            mag_min.append(np.nan)
            
        else:  
            mag_min.append(min(mag))

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(mag_min, bins=100, color='skyblue', edgecolor='dodgerblue', alpha=0.5)

plt.title('Minimal magnitude (Gaussian)')
plt.xlabel('minimal magnitude (in days)')
plt.ylabel('number of GRBs')
# Out:
# Text(0, 0.5, 'number of GRBs')

# %% [markdown]
# #### Mean time of minimal magnitude

# %%
time_max = []

for i in range(len(lc_open)):
    
    if lc_open[i]==0:
        time_max.append(np.nan)
        
    else:
        time_norm = lc_open[i]['time'] - min(lc_open[i]['time'])
        index_max = lc_open[i]['mags'].index(min(lc_open[i]['mags']))
        t_max = time_norm[index_max]

        time_max.append(t_max)

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(time_max, bins=100, color='skyblue', edgecolor='dodgerblue', alpha=0.5)
#plt.hist(time_max, bins=100, alpha=0.5)

plt.title('Minimal magnitude time (Gaussian)')
plt.xlabel('time since first detection (in days)')
plt.ylabel('number of GRBs')
# Out:
# Text(0, 0.5, 'number of GRBs')

# %% [markdown]
# #### $t_{max} - t_0$

# %%
Dt = []

for i in range(len(lc_open)):
    
    mag_u, time_u = [], []
    mag_g, time_g = [], []
    mag_r, time_r = [], []
    mag_i, time_i = [], []
    mag_z, time_z = [], []
    mag_y, time_y = [], []
    
    if lc_open[i]==0:
        
        Dt.append(np.nan)
        
    else:
        
        for j in range(len(lc_open[i]['mags'])):
            
            if lc_open[i]['mags'][j] < lc_open[i]['mags_lim'][j]:
                if lc_open[i]['filt'][j]=='b':
                    mag_u.append(lc_open[i]['mags'][j])
                    time_u.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='c':
                    mag_g.append(lc_open[i]['mags'][j])
                    time_g.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='g':
                    mag_r.append(lc_open[i]['mags'][j])
                    time_r.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='orange':
                    mag_i.append(lc_open[i]['mags'][j])
                    time_i.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='r':
                    mag_z.append(lc_open[i]['mags'][j])
                    time_z.append(lc_open[i]['time'][j])
                else:
                    mag_y.append(lc_open[i]['mags'][j])
                    time_y.append(lc_open[i]['time'][j])
                    
        mag_list = [mag_u, mag_g, mag_r, mag_i, mag_z, mag_y]
        time_list = [time_u, time_g, time_r, time_i, time_z, time_y]
        mag_len = [len(i) for i in mag_list]
        
        mags = mag_list[mag_len.index(max(mag_len))]
        time = time_list[mag_len.index(max(mag_len))]
        
        if len(mags)!=0:
            Dt.append(time[mags.index(min(mags))] - time[0])
        else:
            Dt.append(np.nan)

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(Dt, bins=100, alpha=0.5, color='skyblue', edgecolor='dodgerblue')

plt.title(r'$t_{max} + t_0$ (Gaussian)')
plt.xlabel(r'$t_{max} + t_0$ (in days)')
plt.ylabel('number of GRBs')
# Out:
# Text(0, 0.5, 'number of GRBs')

# %% [markdown]
# #### Mean decreasing rate

# %%
rate_dec = []
rate_inc = []

for i in range(len(lc_open)):
    
    mag_u, time_u = [], []
    mag_g, time_g = [], []
    mag_r, time_r = [], []
    mag_i, time_i = [], []
    mag_z, time_z = [], []
    mag_y, time_y = [], []
    
    if lc_open[i]==0:
        rate_dec.append(np.nan)
        rate_inc.append(np.nan)
        
    else:
        for j in range(len(lc_open[i]['mags'])):
            if lc_open[i]['mags'][j] < lc_open[i]['mags_lim'][j]:
                if lc_open[i]['filt'][j]=='b':
                    mag_u.append(lc_open[i]['mags'][j])
                    time_u.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='c':
                    mag_g.append(lc_open[i]['mags'][j])
                    time_g.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='g':
                    mag_r.append(lc_open[i]['mags'][j])
                    time_r.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='orange':
                    mag_i.append(lc_open[i]['mags'][j])
                    time_i.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='r':
                    mag_z.append(lc_open[i]['mags'][j])
                    time_z.append(lc_open[i]['time'][j])
                else:
                    mag_y.append(lc_open[i]['mags'][j])
                    time_y.append(lc_open[i]['time'][j])
                    
        mag_list = [mag_u, mag_g, mag_r, mag_i, mag_z, mag_y]
        time_list = [time_u, time_g, time_r, time_i, time_z, time_y]
        mag_len = [len(i) for i in mag_list]
        
        mags = mag_list[mag_len.index(max(mag_len))]
        time = time_list[mag_len.index(max(mag_len))]
    
    
        if len(mags)!=0 and mags.index(min(mags))<mags.index(max(mags)):        
            
            if mags.index(min(mags))==0:
            
                index_min = mags.index(min(mags))
                index_max = mags.index(max(mags))
                rate_dec.append((mags[index_max] - mags[index_min])/(time[index_max] - time[index_min]))
                
                rate_inc.append(np.nan)
                
            else:
                
                index_min = mags.index(min(mags))
                index_max = mags.index(max(mags))
                rate_dec.append((mags[index_max] - mags[index_min])/(time[index_max] - time[index_min]))
                
                mags2 = mags[0:index_min]
                index_max2 = mags.index(max(mags2))
                rate_inc.append((mags[index_min] - mags[index_max2])/(time[index_min] - time[index_max2]))
                
            
        elif len(mags)!=0 and mags.index(min(mags))>mags.index(max(mags)):
            
            if mags.index(min(mags))==(len(mags)-1):
                
                index_min = mags.index(min(mags))
                index_max = mags.index(max(mags))
                rate_inc.append((mags[index_min] - mags[index_max])/(time[index_min] - time[index_max]))
                
                rate_dec.append(np.nan)
                
            else:
                
                index_min = mags.index(min(mags))
                
                index_max = mags.index(max(mags))
                rate_inc.append((mags[index_min] - mags[index_max])/(time[index_min] - time[index_max]))
                
                mags2 = mags[index_min:(len(lc_open[i]['mags'])-1)]
                index_max2 = mags.index(max(mags2))
                rate_dec.append((mags[index_max2] - mags[index_min])/(time[index_max2] - time[index_min]))
                
        else:
            rate_inc.append(np.nan)
            rate_dec.append(np.nan)

# %%
rate_dec_not_nan = [x for x in rate_dec if not math.isnan(x)]
rate_inc_not_nan = [x for x in rate_inc if not math.isnan(x)]

print('Mean decreasing rate = %.2f mag/days, standard deviation = %.2f' %(np.mean(rate_dec_not_nan), np.std(rate_dec_not_nan)))
print('Mean increasing rate = %.2f mag/days, standard deviation = %.2f' %(np.mean(rate_inc_not_nan), np.std(rate_inc_not_nan)))

fig = plt.figure(figsize=(13,10))

plt.hist(rate_dec, bins=30, label='decreasing rate', color='skyblue', edgecolor='dodgerblue', alpha=0.5)
plt.hist(rate_inc, bins=100, label='increasing rate', color='orange', edgecolor='orangered', alpha=0.5)

plt.title('Decreasing/increasing rate (Gaussian)')
plt.xlabel('rate (in mag/days)')
plt.ylabel('number of GRBs')

plt.axvline(x=np.mean(rate_dec_not_nan), color='blue', linestyle=':', label='mean decreasing rate')
plt.axvline(x=np.mean(rate_inc_not_nan), color='darkorange', linestyle=':', label='mean increasing rate')
plt.legend()
# Out:
# Mean decreasing rate = 0.11 mag/days, standard deviation = 0.23
# Mean increasing rate = -0.26 mag/days, standard deviation = 2.14

# %% [markdown]
# #### g-r color

# %%
color = []

for i in range(len(lc_open)):
    
    color_inf = []
    color_sup = []
    color_one = []
    
    mag_u, time_u = [], []
    mag_g, time_g = [], []
    mag_r, time_r = [], []
    mag_i, time_i = [], []
    mag_z, time_z = [], []
    mag_y, time_y = [], []
    
    if lc_open[i]==0:
        
        color.append(np.nan)
        
    else:
        
        for j in range(len(lc_open[i]['mags'])):
            
            if lc_open[i]['mags'][j] < lc_open[i]['mags_lim'][j]:
                if lc_open[i]['filt'][j]=='c':
                    mag_g.append(lc_open[i]['mags'][j])
                    time_g.append(lc_open[i]['time'][j])
                elif lc_open[i]['filt'][j]=='g':
                    mag_r.append(lc_open[i]['mags'][j])
                    time_r.append(lc_open[i]['time'][j])
                    
    
        if len(mag_r)!=0 and len(mag_g)!=0:

            for k in range(min(len(mag_r), len(mag_g))):
                if abs(time_g[k] - time_r[k]) < 0.5:

                    if (mag_g[k] - mag_r[k]) < 0.22:
                        color_inf.append(mag_g[k] - mag_r[k])
                        color_one.append((mag_g[k] - mag_r[k]) + (0.22 - np.mean(color_inf)))

                    else:
                        color_sup.append(mag_g[k] - mag_r[k])
                        color_one.append((mag_g[k] - mag_r[k]) + (0.22 - np.mean(color_sup)))
                
            color.append(np.mean(color_one))
            
        else:
            color.append(np.nan)
# Out:
# C:\Users\Marina\Documents\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Marina\Documents\Anaconda\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig = plt.figure(figsize=(10,8))

plt.hist(color, bins=100, color='skyblue', edgecolor='dodgerblue', alpha=0.5)

plt.title('g-r color (Gaussian)')
plt.xlabel('color (in mag)')
plt.ylabel('number of GRBs')
# Out:
# Text(0, 0.5, 'number of GRBs')

# %% [markdown]
# ### Correlations

# %% [markdown]
# #### PairGrid

# %%
results = pd.DataFrame(list(zip(mag_min, time_max, rate_dec, rate_inc, color, Dt)), columns=['mag_min', 'time_max', 'rate_dec', 'rate_inc', 'color', 'tmax-t0'])
results
# Out:
#         mag_min    time_max  rate_dec  rate_inc  color    tmax-t0
# 0           NaN    0.024450       NaN       NaN    NaN        NaN
# 1     20.249085    5.014072       NaN -0.068504   0.22   9.934283
# 2     19.888812    0.000000  0.006347       NaN    NaN   0.000000
# 3     19.737538    0.068852  0.492033       NaN    NaN   0.000000
# 4           NaN    0.000000       NaN       NaN    NaN        NaN
# ...         ...         ...       ...       ...    ...        ...
# 4196        NaN    0.013734       NaN       NaN    NaN        NaN
# 4197  20.184619  139.703653       NaN -0.032494   0.22  63.954820
# 4198        NaN    0.000000       NaN       NaN    NaN        NaN
# 4199  21.657649    0.022393       NaN       NaN    NaN   0.000000
# 4200        NaN    0.024206       NaN       NaN    NaN        NaN
#
# [4201 rows x 6 columns]

# %%
results = results[(results['time_max'] < 150) 
                  & (results['rate_dec'] < 0.25) 
                  & (results['rate_inc'] > -1)
                  & (results['color'] > 0.21)
                  & (results['color'] < 0.225)
                  & (results['tmax-t0'] < 100)]

# %%
results_not_zeros = results[(results['time_max'] > 0) & (results['tmax-t0'] > 0)]

# %%
results_not_zeros
# Out:
#         mag_min   time_max  rate_dec  rate_inc     color    tmax-t0
# 34    17.851942   3.880232  0.042968 -0.010964  0.220000   0.008848
# 136   21.424417  15.999293  0.022835 -0.056219  0.220000  25.981760
# 162   18.781308   3.910165  0.108384 -0.361277  0.220000   4.931566
# 198   21.652804  16.074349  0.044878 -0.297775  0.211536   5.918529
# 236   20.625630  83.793288  0.011574 -0.012853  0.219999  20.921248
# ...         ...        ...       ...       ...       ...        ...
# 3979  21.428481  48.097837  0.003628 -0.012438  0.220025  37.067376
# 4101  20.594106   0.023945  0.088070 -0.071887  0.220000   0.000447
# 4150  20.459805   7.078077  0.066632 -0.093688  0.219399   6.862201
# 4154  19.180079  32.886154  0.011827 -0.043001  0.220000  31.861886
# 4166  21.195074  92.700191  0.007150 -0.039018  0.220000  60.876190
#
# [85 rows x 6 columns]

# %%
# correlations with values of tmax and tmax - t0 = 0

sns.set_theme(style="darkgrid")

g = sns.PairGrid(results, diag_sharey=False)
g.map_upper(sns.scatterplot, s=15, alpha=0.2)
g.map_upper(sns.histplot, bins=30, cmap='viridis')
g.map_lower(sns.kdeplot, cmap='viridis')
g.map_diag(sns.kdeplot, color='midnightblue', lw=1.5)

# %%
# correlations without values of tmax and tmax - t0 = 0

sns.set_theme(style="darkgrid")

g = sns.PairGrid(results_not_zeros, diag_sharey=False)
g.map_upper(sns.scatterplot, s=15, alpha=0.2)
g.map_upper(sns.histplot, bins=30, cmap='viridis')
g.map_lower(sns.kdeplot, cmap='viridis')
g.map_diag(sns.kdeplot, color='midnightblue', lw=1.5)

# %% [markdown]
# #### Heatmap

# %%
lc_param = []

dict_nan = {'jetType': -1,
      'specType': 0,
      'b': 4,
      'thetaObs': np.nan,
      'E0': np.nan,
      'thetaWing': np.nan,
      'thetaCore': 0.15,
      'n0': np.nan,
      'p': 2.2,
      'epsilon_e': 0.1,
      'epsilon_B': 0.01,
      'xi_N': 1.0,
      'd_L': 1.0e+28,
      'z': np.nan}

for i in range(len(lc_open)):
    if lc_open[i] == 0:
        lc_param.append(dict_nan)
    else:
        lc_param.append(lc_open[i]['config'])

# %%
df = pd.DataFrame(lc_param, columns = ['E0', 'n0', 'z', 'thetaObs', 'thetaWing'])

# %%
sns.set_theme(style="darkgrid")

df['log10(E0)'] = np.log10(df['E0'])
df['log10(n0)'] = np.log10(df['n0'])
df['cos(thetaObs)'] = np.cos(df['thetaObs'])
df['cos(thetaWing)'] = np.cos(df['thetaWing'])
df['thetaObs-thetaWing'] = df['thetaObs'] - df['thetaWing']
df['cos(thetaObs)-cos(thetaWing)'] = np.cos(df['thetaObs']) - np.cos(df['thetaWing'])

# %%
df.corr()
# Out:
#                                     E0        n0         z  thetaObs  \
# E0                            1.000000 -0.011471  0.041442  0.130896
# n0                           -0.011471  1.000000  0.015416  0.196385
# z                             0.041442  0.015416  1.000000 -0.376113
# thetaObs                      0.130896  0.196385 -0.376113  1.000000
# thetaWing                     0.019940  0.011107 -0.026729  0.049278
# log10(E0)                     0.334977 -0.097105  0.199716  0.297984
# log10(n0)                    -0.024078  0.812307  0.020820  0.256217
# cos(thetaObs)                -0.118831 -0.140663  0.341090 -0.948927
# cos(thetaWing)               -0.014892 -0.016213  0.023734 -0.043493
# thetaObs-thetaWing            0.106233  0.168878 -0.320677  0.863607
# cos(thetaObs)-cos(thetaWing) -0.106875 -0.127031  0.313765 -0.881195
#
#                               thetaWing  log10(E0)  log10(n0)  cos(thetaObs)  \
# E0                             0.019940   0.334977  -0.024078      -0.118831
# n0                             0.011107  -0.097105   0.812307      -0.140663
# z                             -0.026729   0.199716   0.020820       0.341090
# thetaObs                       0.049278   0.297984   0.256217      -0.948927
# thetaWing                      1.000000   0.013305   0.013080      -0.047443
# log10(E0)                      0.013305   1.000000  -0.121156      -0.253292
# log10(n0)                      0.013080  -0.121156   1.000000      -0.181928
# cos(thetaObs)                 -0.047443  -0.253292  -0.181928       1.000000
# cos(thetaWing)                -0.970167  -0.009321  -0.015316       0.041972
# thetaObs-thetaWing            -0.460996   0.258037   0.221042      -0.819156
# cos(thetaObs)-cos(thetaWing)   0.311946  -0.236054  -0.166377       0.930043
#
#                               cos(thetaWing)  thetaObs-thetaWing  \
# E0                                 -0.014892            0.106233
# n0                                 -0.016213            0.168878
# z                                   0.023734           -0.320677
# thetaObs                           -0.043493            0.863607
# thetaWing                          -0.970167           -0.460996
# log10(E0)                          -0.009321            0.258037
# log10(n0)                          -0.015316            0.221042
# cos(thetaObs)                       0.041972           -0.819156
# cos(thetaWing)                      1.000000            0.451077
# thetaObs-thetaWing                  0.451077            1.000000
# cos(thetaObs)-cos(thetaWing)       -0.328091           -0.940389
#
#                               cos(thetaObs)-cos(thetaWing)
# E0                                               -0.106875
# n0                                               -0.127031
# z                                                 0.313765
# thetaObs                                         -0.881195
# thetaWing                                         0.311946
# log10(E0)                                        -0.236054
# log10(n0)                                        -0.166377
# cos(thetaObs)                                     0.930043
# cos(thetaWing)                                   -0.328091
# thetaObs-thetaWing                               -0.940389
# cos(thetaObs)-cos(thetaWing)                      1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, center=0);

# %%
all_results = pd.concat([df, results], axis=1)
all_results['log(time_max)'] = np.log10(all_results['time_max'])
all_results['log(tmax-t0)'] = np.log10(all_results['tmax-t0'])
all_results
# Out:
# C:\Users\Marina\Documents\Anaconda\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                 E0        n0      z  thetaObs  thetaWing  log10(E0)  \
# 0     2.957908e+51  0.291157  0.046  0.169723   0.174191  51.470985
# 1     4.170676e+51  0.024389  0.024  0.203739   0.242584  51.620207
# 2     1.378934e+54  0.065187  0.060  0.389902   0.151648  54.139543
# 3     1.223144e+51  0.416140  0.040  0.221476   0.208787  51.087478
# 4     3.069332e+51  0.007796  0.090  0.184760   0.206377  51.487044
# ...            ...       ...    ...       ...        ...        ...
# 4196  1.359979e+51  0.013865  0.034  0.188001   0.165092  51.133532
# 4197  3.290382e+52  0.315996  0.006  0.885959   0.279413  52.517246
# 4198  2.369220e+52  0.001258  0.056  0.166448   0.225099  52.374605
# 4199  3.741203e+51  0.044052  0.076  0.195539   0.202374  51.573011
# 4200  1.853794e+50  0.110731  0.010  0.259815   0.153486  50.268061
#
#       log10(n0)  cos(thetaObs)  cos(thetaWing)  thetaObs-thetaWing  \
# 0     -0.535873       0.985632        0.984867           -0.004468
# 1     -1.612810       0.979317        0.970720           -0.038845
# 2     -1.185841       0.924946        0.988524            0.238255
# 3     -0.380760       0.975574        0.978283            0.012689
# 4     -2.108104       0.982980        0.978780           -0.021618
# ...         ...            ...             ...                 ...
# 4196  -1.858091       0.982380        0.986403            0.022909
# 4197  -0.500318       0.632547        0.961218            0.606546
# 4198  -2.900261       0.986179        0.974772           -0.058651
# 4199  -1.356030       0.980943        0.979592           -0.006835
# 4200  -0.955733       0.966438        0.988244            0.106329
#
#       cos(thetaObs)-cos(thetaWing)  mag_min  time_max  rate_dec  rate_inc  \
# 0                         0.000764      NaN       NaN       NaN       NaN
# 1                         0.008596      NaN       NaN       NaN       NaN
# 2                        -0.063577      NaN       NaN       NaN       NaN
# 3                        -0.002709      NaN       NaN       NaN       NaN
# 4                         0.004201      NaN       NaN       NaN       NaN
# ...                            ...      ...       ...       ...       ...
# 4196                     -0.004023      NaN       NaN       NaN       NaN
# 4197                     -0.328671      NaN       NaN       NaN       NaN
# 4198                      0.011407      NaN       NaN       NaN       NaN
# 4199                      0.001351      NaN       NaN       NaN       NaN
# 4200                     -0.021807      NaN       NaN       NaN       NaN
#
#       color  tmax-t0  log(time_max)  log(tmax-t0)
# 0       NaN      NaN            NaN           NaN
# 1       NaN      NaN            NaN           NaN
# 2       NaN      NaN            NaN           NaN
# 3       NaN      NaN            NaN           NaN
# 4       NaN      NaN            NaN           NaN
# ...     ...      ...            ...           ...
# 4196    NaN      NaN            NaN           NaN
# 4197    NaN      NaN            NaN           NaN
# 4198    NaN      NaN            NaN           NaN
# 4199    NaN      NaN            NaN           NaN
# 4200    NaN      NaN            NaN           NaN
#
# [4201 rows x 19 columns]

# %%
all_results_not_zeros = pd.concat([df, results_not_zeros], axis=1)
all_results_not_zeros['log(time_max)'] = np.log10(all_results_not_zeros['time_max'])
all_results_not_zeros['log(tmax-t0)'] = np.log10(all_results_not_zeros['tmax-t0'])
all_results_not_zeros
# Out:
#                 E0        n0      z  thetaObs  thetaWing  log10(E0)  \
# 0     2.957908e+51  0.291157  0.046  0.169723   0.174191  51.470985
# 1     4.170676e+51  0.024389  0.024  0.203739   0.242584  51.620207
# 2     1.378934e+54  0.065187  0.060  0.389902   0.151648  54.139543
# 3     1.223144e+51  0.416140  0.040  0.221476   0.208787  51.087478
# 4     3.069332e+51  0.007796  0.090  0.184760   0.206377  51.487044
# ...            ...       ...    ...       ...        ...        ...
# 4196  1.359979e+51  0.013865  0.034  0.188001   0.165092  51.133532
# 4197  3.290382e+52  0.315996  0.006  0.885959   0.279413  52.517246
# 4198  2.369220e+52  0.001258  0.056  0.166448   0.225099  52.374605
# 4199  3.741203e+51  0.044052  0.076  0.195539   0.202374  51.573011
# 4200  1.853794e+50  0.110731  0.010  0.259815   0.153486  50.268061
#
#       log10(n0)  cos(thetaObs)  cos(thetaWing)  thetaObs-thetaWing  \
# 0     -0.535873       0.985632        0.984867           -0.004468
# 1     -1.612810       0.979317        0.970720           -0.038845
# 2     -1.185841       0.924946        0.988524            0.238255
# 3     -0.380760       0.975574        0.978283            0.012689
# 4     -2.108104       0.982980        0.978780           -0.021618
# ...         ...            ...             ...                 ...
# 4196  -1.858091       0.982380        0.986403            0.022909
# 4197  -0.500318       0.632547        0.961218            0.606546
# 4198  -2.900261       0.986179        0.974772           -0.058651
# 4199  -1.356030       0.980943        0.979592           -0.006835
# 4200  -0.955733       0.966438        0.988244            0.106329
#
#       cos(thetaObs)-cos(thetaWing)  mag_min  time_max  rate_dec  rate_inc  \
# 0                         0.000764      NaN       NaN       NaN       NaN
# 1                         0.008596      NaN       NaN       NaN       NaN
# 2                        -0.063577      NaN       NaN       NaN       NaN
# 3                        -0.002709      NaN       NaN       NaN       NaN
# 4                         0.004201      NaN       NaN       NaN       NaN
# ...                            ...      ...       ...       ...       ...
# 4196                     -0.004023      NaN       NaN       NaN       NaN
# 4197                     -0.328671      NaN       NaN       NaN       NaN
# 4198                      0.011407      NaN       NaN       NaN       NaN
# 4199                      0.001351      NaN       NaN       NaN       NaN
# 4200                     -0.021807      NaN       NaN       NaN       NaN
#
#       color  tmax-t0  log(time_max)  log(tmax-t0)
# 0       NaN      NaN            NaN           NaN
# 1       NaN      NaN            NaN           NaN
# 2       NaN      NaN            NaN           NaN
# 3       NaN      NaN            NaN           NaN
# 4       NaN      NaN            NaN           NaN
# ...     ...      ...            ...           ...
# 4196    NaN      NaN            NaN           NaN
# 4197    NaN      NaN            NaN           NaN
# 4198    NaN      NaN            NaN           NaN
# 4199    NaN      NaN            NaN           NaN
# 4200    NaN      NaN            NaN           NaN
#
# [4201 rows x 19 columns]

# %%
#all_results = all_results.dropna()
all_results.corr()
# Out:
#                                     E0        n0         z  thetaObs  \
# E0                            1.000000 -0.011471  0.041442  0.130896
# n0                           -0.011471  1.000000  0.015416  0.196385
# z                             0.041442  0.015416  1.000000 -0.376113
# thetaObs                      0.130896  0.196385 -0.376113  1.000000
# thetaWing                     0.019940  0.011107 -0.026729  0.049278
# log10(E0)                     0.334977 -0.097105  0.199716  0.297984
# log10(n0)                    -0.024078  0.812307  0.020820  0.256217
# cos(thetaObs)                -0.118831 -0.140663  0.341090 -0.948927
# cos(thetaWing)               -0.014892 -0.016213  0.023734 -0.043493
# thetaObs-thetaWing            0.106233  0.168878 -0.320677  0.863607
# cos(thetaObs)-cos(thetaWing) -0.106875 -0.127031  0.313765 -0.881195
# mag_min                      -0.393659  0.056175  0.027893  0.334582
# time_max                      0.010822 -0.040018 -0.231467  0.662986
# rate_dec                     -0.199934  0.215026  0.082762 -0.354353
# rate_inc                      0.013230 -0.096206 -0.019167  0.255841
# color                         0.048058 -0.068492 -0.055239  0.023300
# tmax-t0                      -0.005116 -0.013716 -0.211101  0.496940
# log(time_max)                -0.027805  0.006857 -0.094676  0.421416
# log(tmax-t0)                  0.025392 -0.064653 -0.060598  0.255038
#
#                               thetaWing  log10(E0)  log10(n0)  cos(thetaObs)  \
# E0                             0.019940   0.334977  -0.024078      -0.118831
# n0                             0.011107  -0.097105   0.812307      -0.140663
# z                             -0.026729   0.199716   0.020820       0.341090
# thetaObs                       0.049278   0.297984   0.256217      -0.948927
# thetaWing                      1.000000   0.013305   0.013080      -0.047443
# log10(E0)                      0.013305   1.000000  -0.121156      -0.253292
# log10(n0)                      0.013080  -0.121156   1.000000      -0.181928
# cos(thetaObs)                 -0.047443  -0.253292  -0.181928       1.000000
# cos(thetaWing)                -0.970167  -0.009321  -0.015316       0.041972
# thetaObs-thetaWing            -0.460996   0.258037   0.221042      -0.819156
# cos(thetaObs)-cos(thetaWing)   0.311946  -0.236054  -0.166377       0.930043
# mag_min                        0.122368  -0.306790   0.034550      -0.310902
# time_max                      -0.087596   0.251920  -0.011458      -0.664057
# rate_dec                      -0.054447  -0.581373   0.310050       0.330440
# rate_inc                       0.112374   0.292055  -0.152476      -0.246462
# color                         -0.145255   0.117052  -0.173538      -0.048069
# tmax-t0                       -0.152908   0.278700  -0.056743      -0.492291
# log(time_max)                 -0.162610   0.213396   0.016969      -0.398606
# log(tmax-t0)                  -0.317139   0.222296  -0.096168      -0.237783
#
#                               cos(thetaWing)  thetaObs-thetaWing  \
# E0                                 -0.014892            0.106233
# n0                                 -0.016213            0.168878
# z                                   0.023734           -0.320677
# thetaObs                           -0.043493            0.863607
# thetaWing                          -0.970167           -0.460996
# log10(E0)                          -0.009321            0.258037
# log10(n0)                          -0.015316            0.221042
# cos(thetaObs)                       0.041972           -0.819156
# cos(thetaWing)                      1.000000            0.451077
# thetaObs-thetaWing                  0.451077            1.000000
# cos(thetaObs)-cos(thetaWing)       -0.328091           -0.940389
# mag_min                            -0.144109            0.265612
# time_max                            0.088746            0.658113
# rate_dec                            0.069259           -0.311314
# rate_inc                           -0.121184            0.195594
# color                               0.124813            0.079898
# tmax-t0                             0.155878            0.528125
# log(time_max)                       0.157898            0.461959
# log(tmax-t0)                        0.322563            0.366337
#
#                               cos(thetaObs)-cos(thetaWing)   mag_min  \
# E0                                               -0.106875 -0.393659
# n0                                               -0.127031  0.056175
# z                                                 0.313765  0.027893
# thetaObs                                         -0.881195  0.334582
# thetaWing                                         0.311946  0.122368
# log10(E0)                                        -0.236054 -0.306790
# log10(n0)                                        -0.166377  0.034550
# cos(thetaObs)                                     0.930043 -0.310902
# cos(thetaWing)                                   -0.328091 -0.144109
# thetaObs-thetaWing                               -0.940389  0.265612
# cos(thetaObs)-cos(thetaWing)                      1.000000 -0.272924
# mag_min                                          -0.272924  1.000000
# time_max                                         -0.674219  0.159825
# rate_dec                                          0.309390 -0.118031
# rate_inc                                         -0.214758  0.160095
# color                                            -0.076056 -0.056572
# tmax-t0                                          -0.520561  0.043606
# log(time_max)                                    -0.429145  0.040414
# log(tmax-t0)                                     -0.308356 -0.146857
#
#                               time_max  rate_dec  rate_inc     color  \
# E0                            0.010822 -0.199934  0.013230  0.048058
# n0                           -0.040018  0.215026 -0.096206 -0.068492
# z                            -0.231467  0.082762 -0.019167 -0.055239
# thetaObs                      0.662986 -0.354353  0.255841  0.023300
# thetaWing                    -0.087596 -0.054447  0.112374 -0.145255
# log10(E0)                     0.251920 -0.581373  0.292055  0.117052
# log10(n0)                    -0.011458  0.310050 -0.152476 -0.173538
# cos(thetaObs)                -0.664057  0.330440 -0.246462 -0.048069
# cos(thetaWing)                0.088746  0.069259 -0.121184  0.124813
# thetaObs-thetaWing            0.658113 -0.311314  0.195594  0.079898
# cos(thetaObs)-cos(thetaWing) -0.674219  0.309390 -0.214758 -0.076056
# mag_min                       0.159825 -0.118031  0.160095 -0.056572
# time_max                      1.000000 -0.483462  0.354310  0.138711
# rate_dec                     -0.483462  1.000000 -0.418920 -0.052146
# rate_inc                      0.354310 -0.418920  1.000000  0.362085
# color                         0.138711 -0.052146  0.362085  1.000000
# tmax-t0                       0.799263 -0.414438  0.327253  0.106466
# log(time_max)                 0.679601 -0.382078  0.185626  0.085611
# log(tmax-t0)                  0.473929 -0.287120  0.136253  0.051898
#
#                                tmax-t0  log(time_max)  log(tmax-t0)
# E0                           -0.005116      -0.027805      0.025392
# n0                           -0.013716       0.006857     -0.064653
# z                            -0.211101      -0.094676     -0.060598
# thetaObs                      0.496940       0.421416      0.255038
# thetaWing                    -0.152908      -0.162610     -0.317139
# log10(E0)                     0.278700       0.213396      0.222296
# log10(n0)                    -0.056743       0.016969     -0.096168
# cos(thetaObs)                -0.492291      -0.398606     -0.237783
# cos(thetaWing)                0.155878       0.157898      0.322563
# thetaObs-thetaWing            0.528125       0.461959      0.366337
# cos(thetaObs)-cos(thetaWing) -0.520561      -0.429145     -0.308356
# mag_min                       0.043606       0.040414     -0.146857
# time_max                      0.799263       0.679601      0.473929
# rate_dec                     -0.414438      -0.382078     -0.287120
# rate_inc                      0.327253       0.185626      0.136253
# color                         0.106466       0.085611      0.051898
# tmax-t0                       1.000000       0.587109      0.613140
# log(time_max)                 0.587109       1.000000      0.750157
# log(tmax-t0)                  0.613140       0.750157      1.000000

# %%
#all_results_not_zeros = all_results_not_zeros.dropna()
all_results_not_zeros.corr()
# Out:
#                                     E0        n0         z  thetaObs  \
# E0                            1.000000 -0.011471  0.041442  0.130896
# n0                           -0.011471  1.000000  0.015416  0.196385
# z                             0.041442  0.015416  1.000000 -0.376113
# thetaObs                      0.130896  0.196385 -0.376113  1.000000
# thetaWing                     0.019940  0.011107 -0.026729  0.049278
# log10(E0)                     0.334977 -0.097105  0.199716  0.297984
# log10(n0)                    -0.024078  0.812307  0.020820  0.256217
# cos(thetaObs)                -0.118831 -0.140663  0.341090 -0.948927
# cos(thetaWing)               -0.014892 -0.016213  0.023734 -0.043493
# thetaObs-thetaWing            0.106233  0.168878 -0.320677  0.863607
# cos(thetaObs)-cos(thetaWing) -0.106875 -0.127031  0.313765 -0.881195
# mag_min                      -0.396413  0.057603  0.031683  0.331842
# time_max                      0.006069 -0.036999 -0.224689  0.657608
# rate_dec                     -0.211678  0.238730  0.046833 -0.322778
# rate_inc                      0.011618 -0.095205 -0.016204  0.253190
# color                         0.050096 -0.069915 -0.059085  0.031022
# tmax-t0                      -0.009555 -0.010793 -0.204693  0.489386
# log(time_max)                -0.027805  0.006857 -0.094676  0.421416
# log(tmax-t0)                  0.014836 -0.059149 -0.041596  0.223877
#
#                               thetaWing  log10(E0)  log10(n0)  cos(thetaObs)  \
# E0                             0.019940   0.334977  -0.024078      -0.118831
# n0                             0.011107  -0.097105   0.812307      -0.140663
# z                             -0.026729   0.199716   0.020820       0.341090
# thetaObs                       0.049278   0.297984   0.256217      -0.948927
# thetaWing                      1.000000   0.013305   0.013080      -0.047443
# log10(E0)                      0.013305   1.000000  -0.121156      -0.253292
# log10(n0)                      0.013080  -0.121156   1.000000      -0.181928
# cos(thetaObs)                 -0.047443  -0.253292  -0.181928       1.000000
# cos(thetaWing)                -0.970167  -0.009321  -0.015316       0.041972
# thetaObs-thetaWing            -0.460996   0.258037   0.221042      -0.819156
# cos(thetaObs)-cos(thetaWing)   0.311946  -0.236054  -0.166377       0.930043
# mag_min                        0.123837  -0.318211   0.038320      -0.307876
# time_max                      -0.085027   0.238835  -0.002690      -0.659303
# rate_dec                      -0.083891  -0.601358   0.320954       0.315292
# rate_inc                       0.113567   0.289867  -0.150058      -0.243778
# color                         -0.146732   0.125798  -0.177824      -0.054280
# tmax-t0                       -0.150894   0.267387  -0.049123      -0.485787
# log(time_max)                 -0.162610   0.213396   0.016969      -0.398606
# log(tmax-t0)                  -0.320953   0.190651  -0.078788      -0.214066
#
#                               cos(thetaWing)  thetaObs-thetaWing  \
# E0                                 -0.014892            0.106233
# n0                                 -0.016213            0.168878
# z                                   0.023734           -0.320677
# thetaObs                           -0.043493            0.863607
# thetaWing                          -0.970167           -0.460996
# log10(E0)                          -0.009321            0.258037
# log10(n0)                          -0.015316            0.221042
# cos(thetaObs)                       0.041972           -0.819156
# cos(thetaWing)                      1.000000            0.451077
# thetaObs-thetaWing                  0.451077            1.000000
# cos(thetaObs)-cos(thetaWing)       -0.328091           -0.940389
# mag_min                            -0.144906            0.261884
# time_max                            0.087776            0.652630
# rate_dec                            0.092143           -0.269520
# rate_inc                           -0.121805            0.192095
# color                               0.125574            0.088516
# tmax-t0                             0.155310            0.521122
# log(time_max)                       0.157898            0.461959
# log(tmax-t0)                        0.330312            0.340295
#
#                               cos(thetaObs)-cos(thetaWing)   mag_min  \
# E0                                               -0.106875 -0.396413
# n0                                               -0.127031  0.057603
# z                                                 0.313765  0.031683
# thetaObs                                         -0.881195  0.331842
# thetaWing                                         0.311946  0.123837
# log10(E0)                                        -0.236054 -0.318211
# log10(n0)                                        -0.166377  0.038320
# cos(thetaObs)                                     0.930043 -0.307876
# cos(thetaWing)                                   -0.328091 -0.144906
# thetaObs-thetaWing                               -0.940389  0.261884
# cos(thetaObs)-cos(thetaWing)                      1.000000 -0.269537
# mag_min                                          -0.269537  1.000000
# time_max                                         -0.669579  0.155808
# rate_dec                                          0.289084 -0.111192
# rate_inc                                         -0.211781  0.158623
# color                                            -0.082589 -0.054598
# tmax-t0                                          -0.514391  0.039138
# log(time_max)                                    -0.429145  0.040414
# log(tmax-t0)                                     -0.287439 -0.164553
#
#                               time_max  rate_dec  rate_inc     color  \
# E0                            0.006069 -0.211678  0.011618  0.050096
# n0                           -0.036999  0.238730 -0.095205 -0.069915
# z                            -0.224689  0.046833 -0.016204 -0.059085
# thetaObs                      0.657608 -0.322778  0.253190  0.031022
# thetaWing                    -0.085027 -0.083891  0.113567 -0.146732
# log10(E0)                     0.238835 -0.601358  0.289867  0.125798
# log10(n0)                    -0.002690  0.320954 -0.150058 -0.177824
# cos(thetaObs)                -0.659303  0.315292 -0.243778 -0.054280
# cos(thetaWing)                0.087776  0.092143 -0.121805  0.125574
# thetaObs-thetaWing            0.652630 -0.269520  0.192095  0.088516
# cos(thetaObs)-cos(thetaWing) -0.669579  0.289084 -0.211781 -0.082589
# mag_min                       0.155808 -0.111192  0.158623 -0.054598
# time_max                      1.000000 -0.508874  0.352515  0.144855
# rate_dec                     -0.508874  1.000000 -0.477624 -0.092687
# rate_inc                      0.352515 -0.477624  1.000000  0.364452
# color                         0.144855 -0.092687  0.364452  1.000000
# tmax-t0                       0.796971 -0.431590  0.325296  0.111809
# log(time_max)                 0.679601 -0.382078  0.185626  0.085611
# log(tmax-t0)                  0.463529 -0.179034  0.130943  0.065945
#
#                                tmax-t0  log(time_max)  log(tmax-t0)
# E0                           -0.009555      -0.027805      0.014836
# n0                           -0.010793       0.006857     -0.059149
# z                            -0.204693      -0.094676     -0.041596
# thetaObs                      0.489386       0.421416      0.223877
# thetaWing                    -0.150894      -0.162610     -0.320953
# log10(E0)                     0.267387       0.213396      0.190651
# log10(n0)                    -0.049123       0.016969     -0.078788
# cos(thetaObs)                -0.485787      -0.398606     -0.214066
# cos(thetaWing)                0.155310       0.157898      0.330312
# thetaObs-thetaWing            0.521122       0.461959      0.340295
# cos(thetaObs)-cos(thetaWing) -0.514391      -0.429145     -0.287439
# mag_min                       0.039138       0.040414     -0.164553
# time_max                      0.796971       0.679601      0.463529
# rate_dec                     -0.431590      -0.382078     -0.179034
# rate_inc                      0.325296       0.185626      0.130943
# color                         0.111809       0.085611      0.065945
# tmax-t0                       1.000000       0.587109      0.610548
# log(time_max)                 0.587109       1.000000      0.750157
# log(tmax-t0)                  0.610548       0.750157      1.000000

# %%
plt.figure(figsize=(15, 13))
sns.heatmap(all_results.corr(), annot=True, center=0, mask=all_results.corr().isnull());

# %%
plt.figure(figsize=(15, 13))
sns.heatmap(all_results_not_zeros.corr(), annot=True, center=0, mask=all_results_not_zeros.corr().isnull());
